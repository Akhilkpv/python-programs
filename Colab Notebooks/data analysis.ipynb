# %%
import pandas as pd
data={
      'Title' : ['The Dark Knight','Inception','Titanic','Avatar','The Matrix','The Godfather','Vettam','Marco','Identity','Qalb','Twillight'],
      'Genre' : ['Action','Sci-Fi','Romance','Sci-Fi','Action','Crime','Romance','Crime Thriller','Thriller','Romance','Romance'],
      'Rating' : [9.0, 8.8, 7.8, 7.8, 8.7, 9.2, 9.5, 9.8, 9.3, 8.5, 9.1],
      'Year' : [2008, 2010, 1997, 2009, 1999, 1972, 2004, 2024, 2025, 2023, 2015]
}
df=pd.DataFrame(data)
#print(df)
#print(df.columns)
#print(df.head(5))
#print(df.tail(9))
#print(df.loc[0])
#print(df['Rating'])
#[df['Rating'].idxmax()]
#scifi_movies=df[df['Genre']=='Sci-Fi']
#print(scifi_movies)
#print(scifi_movies[['Title','Rating']])
#new_df=df[['Title','Rating']]
#print(new_df)

#sorting
#df.sort_values(by='Rating',ascending=False)
#df.sort_values(by='Rating',ascending=True)

#add column
#df['watchcount']=[1000, 4000, 5000, 1001, 3000, 6000, 3000, 2500, 3800, 7000,5000]
#print(df['watchcount'])

#movies_watchcount=df[df['watchcount']>2000]
#print(movies_watchcount)
#rounding
#df['Rating Out of 10']= df['Rating'].round(1)
#print(df)
#print(df[['Title','Rating Out of 10']])
#average
#avg_rating_by_genre=df.groupby('Genre')['Rating'].mean()
#print("AVEREGE RATING BY GENRE:")
#print(avg_rating_by_genre)

#graphical representation
import matplotlib.pyplot as plt
df.plot(kind='bar',x='Title',y='Rating',color='pink',legend=True)
plt.title('Movie Ratings')
plt.xlabel('Movies')
plt.ylabel('Rating')
plt.xticks(rotation=45)
plt.show()
