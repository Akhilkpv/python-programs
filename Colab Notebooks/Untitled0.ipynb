# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler

# Example dataset
jobs_data = {
    'job_id': [1, 2, 3],
    'skills': ['Python, ML, Data Science', 'Java, Spring, Backend', 'AWS, DevOps, Docker'],
    'experience': [2, 5, 3],
    'location': ['Remote', 'New York', 'San Francisco']
}

user_profile = {
    'skills': 'Python, Data Science',
    'experience': 2,
    'location': 'Remote'
}

# Feature encoding (simplified for this example)
df = pd.DataFrame(jobs_data)
df['skills_vector'] = df['skills'].apply(lambda x: [1 if skill in x else 0 for skill in ['Python', 'ML', 'Data Science', 'Java', 'AWS', 'Docker']])
user_vector = [[1, 1, 1, 0, 0, 0]]  # User skills vector

# Normalize experience and location (assume location encoding is done)
scaler = StandardScaler()
df['experience_scaled'] = scaler.fit_transform(df[['experience']])
user_experience = scaler.transform([[user_profile['experience']]])

# Combine features for KNN
job_features = list(df['skills_vector'])  # Add more features (e.g., experience) as needed

# Train KNN model
knn = NearestNeighbors(n_neighbors=2, metric='cosine')
knn.fit(job_features)

# Recommend jobs
distances, indices = knn.kneighbors(user_vector)
recommended_jobs = df.iloc[indices[0]]['job_id'].tolist()

print("Recommended Job IDs:", recommended_jobs)
print("Distances:", distances[0])
print("Indices:", indices[0])
# Out:
# Recommended Job IDs: [1, 2]
# Distances: [0. 1.]
# Indices: [0 1]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Import necessary libraries
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler

# Example dataset
jobs_data = {
    'job_id': [1, 2, 3],
    'skills': ['Python, ML, Data Science', 'Java, Spring, Backend', 'AWS, DevOps, Docker'],
    'experience': [2, 5, 3],
    'location': ['Remote', 'New York', 'San Francisco']
}

user_profile = {
    'skills': 'Python, Data Science',
    'experience': 2,
    'location': 'Remote'
}

# Feature encoding (skills simplified for this example)
skill_set = ['Python', 'ML', 'Data Science', 'Java', 'AWS', 'Docker']
df = pd.DataFrame(jobs_data)
df['skills_vector'] = df['skills'].apply(lambda x: [1 if skill in x else 0 for skill in skill_set])
user_vector = [[1, 1, 1, 0, 0, 0]]  # User skills vector for "Python, Data Science"

# Normalize experience (simplified)
scaler = StandardScaler()
df['experience_scaled'] = scaler.fit_transform(df[['experience']])
user_experience = scaler.transform([[user_profile['experience']]])

# Combine features for KNN (here, skills only for simplicity)
job_features = list(df['skills_vector'])

# Train KNN model
knn = NearestNeighbors(n_neighbors=2, metric='cosine')
knn.fit(job_features)

# Recommend jobs
distances, indices = knn.kneighbors(user_vector)
recommended_jobs = df.iloc[indices[0]]['job_id'].tolist()

print("Recommended Job IDs:", recommended_jobs)
# Out:
# Recommended Job IDs: [1, 2]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
